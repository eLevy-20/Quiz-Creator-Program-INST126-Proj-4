# %%
#date and time
#If user enters 'submit' after quiz, records the date and time
from datetime import datetime

now = datetime.now()
date_time_format = now.strftime('%d/%m/%Y %H:%M')
print(f"The date and time are:, {date_time_format}")
##################

#Main
name = input("What is your name: ")
main = input("Are you a student or teacher (S/T): ").upper()
if main == 'S':
    #studentmenu() (define the function above and call it here so student gets redirected to their menu)
else:
    #adminmenu() (define the function above and call it here so admin gets redirected to their menu)

#Student Menu
def studentmenu():
  #ask student View grades or see quiz bank?
    #i.e. input('Would you like to view Grades or see Quiz Bank? (G/Q): ')
      #display quiz bank if choose Q
      #show their grades if not/choose G
  


#Quiz Bank
def quizbank():
  #quiz list
    #based on class code (i.e. INST, PSYC, etc)
  #a-z order
  #print quizzes

  #Ask which quiz to take
    #input quiz code
    #start quiz function

def adminmenu():
  #displays admin Functions 

#Admin Functions
def quizdefiner():
  #select class code
  #create quiz
    #add question
      #add answer
    #store correct answer
    
def quizpresenter():  
    #Starts quiz, asks the student the questions
        #i.e. input('Does 2+2=4 ? (Y/N: ') and student answers 
    #Continues until last question which will tell student to input submit 
        #i.e. input('Please type "Submit": ')
            #if they don't it'll repeat the question
    #When finished, score will be graded by the grader() function and will stored in scorecollection() and show student how they did
    #Takes student back to Quiz Bank

def grader():
  #go through each item. Compare student answer to admin designated correct answer.
  #if student answer is not the same as correct asnwer from quizdefiner, - X %

def scorecollection():
  #display which quiz was taken, the date and time, and user that took quiz

def quizresultpresenter():
  #For admins, shows [date/time] [Name] [Quiz Name] [score] (from scorecollection() )

def adminresults():
  #Display Quiz result presenter data for all users per quiz
  #interacts with admin and quiz result presenter
